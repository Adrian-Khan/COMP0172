# %% [markdown]
# # **MRI Brain Classification**
#
# ## Objective
# In this notebook, you will train a convolutional neural network (ConvNet) to classify white blood cells into two categories:
# 1. Scans of brains with tumors (2D Slices)
# 2. Normal brain scans (2D slices)
#
#
# We will use a custom dataset for this classification task. The exercise will guide you step-by-step from data loading and preparation to building and training a deep learning model and visualizing the saliency maps of the models.
#
# Dataset source: https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection

# %%
# Importing necessary libraries
import tensorflow as tf  # TensorFlow for deep learning
import os  # For handling file paths
import numpy as np  # For data manipulation
import matplotlib.pyplot as plt  # For visualizing the dataset

from tensorflow.keras.preprocessing.image import ImageDataGenerator  # For loading and augmenting image data
from sklearn.model_selection import train_test_split  # For splitting custom dataset into train and test

# %% [markdown]
# ## 👓 1. Download the data
# You will use a custom dataset of images that contain lymphoblasts and normal white blood cells. Make sure the dataset is organized in two folders: "lymphoblast" and "normal", with images placed in their respective folders.

# %%
# Define dataset paths
base_dir = "small_mri" # Update this to the actual path
#base_dir = '/content/drive/MyDrive/train_ood_wbc_resized/'
#normal_dir = os.path.join(base_dir, 'normal')
#lymphoblast_dir = os.path.join(base_dir, 'lymphoblasts')

# Define parameters
#IMG_HEIGHT, IMG_WIDTH = 128, 128
IMG_HEIGHT, IMG_WIDTH = 128, 128
BATCH_SIZE = 16
NUM_EPOCHS=3
RAN_SEED=17

# Use ImageDataGenerator for loading and splitting data
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    validation_split=0.5)  # Split 50% of the data for validation

# Creating train and validation datasets
train_data = datagen.flow_from_directory(
    base_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training',
    seed=RAN_SEED
)

validation_data = datagen.flow_from_directory(
    base_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    seed=RAN_SEED
)

print("Training and validation datasets prepared successfully.")
# Out:
# Found 458 images belonging to 2 classes.
# Found 456 images belonging to 2 classes.
# Training and validation datasets prepared successfully.

# %% [markdown]
# ###  1.2 : Visualize the Dataset
#
# Display 10 images from the training dataset to understand the data better.

# %%
# Function to display a few images from the dataset
def visualize_dataset(dataset, num_images=5):
    plt.figure(figsize=(10, 10))
    for i, (image, label) in enumerate(dataset):
        if i >= num_images:
            break
        plt.subplot(1, num_images, i + 1)
        plt.imshow(image[0])  # Image comes as a batch, so we take the first image
        plt.title("Tumour" if label[0] == 1 else "Normal")
        plt.axis("off")
    plt.show()



# Displaying a few images from the training dataset
visualize_dataset(train_data, num_images=5)

# %% [markdown]
# ## ➡️ 2. Transfer Learning
#
# In this section, you will use a pretrained MobileNet model, leveraging its features similar to the lymphoblasts vs normal white blood cells task.

# %%
import tensorflow
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.layers import Input
# Load MobileNetV2 pretrained on ImageNet and add custom layers for our binary classification task
input_tensor = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
#input_tensor = Input(shape=(IMG_HEIGHT, IMG_WIDTH,1))
# create the base pre-trained model on ImageNet with a custom input tensor
base_model = MobileNet(
    input_tensor=input_tensor,
    include_top=False,  # We do not want the top (classification) layers from MobileNet
    weights='imagenet'  # Load weights pretrained on ImageNet
)

# Freeze the base model to use it as a feature extractor
base_model.trainable = False


x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer

x = Dense(128, activation='relu')(x)
# and a classification layer -- let's say we have 8 classes

predictions = Dense(1, activation='sigmoid')(x)
# this is the model we will train
model_mobilenet = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional MobileNet layers
for layer in base_model.layers:
    layer.trainable = False



# Compile the model
model_mobilenet.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Print the model summary
model_mobilenet.summary()
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_6388\3927794103.py:10: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 64, 64, 32)     │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 64, 64, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 64, 64, 32)     │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_bn                    │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_relu (ReLU)           │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1 (Conv2D)              │ (None, 64, 64, 64)     │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_bn                    │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_relu (ReLU)           │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_2 (ZeroPadding2D)      │ (None, 65, 65, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2 (DepthwiseConv2D)     │ (None, 32, 32, 64)     │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_bn                    │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_relu (ReLU)           │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2 (Conv2D)              │ (None, 32, 32, 128)    │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_bn                    │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_relu (ReLU)           │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3 (DepthwiseConv2D)     │ (None, 32, 32, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_bn                    │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_relu (ReLU)           │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3 (Conv2D)              │ (None, 32, 32, 128)    │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_bn                    │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_relu (ReLU)           │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_4 (ZeroPadding2D)      │ (None, 33, 33, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4 (DepthwiseConv2D)     │ (None, 16, 16, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_bn                    │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_relu (ReLU)           │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4 (Conv2D)              │ (None, 16, 16, 256)    │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_bn                    │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_relu (ReLU)           │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5 (DepthwiseConv2D)     │ (None, 16, 16, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_bn                    │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_relu (ReLU)           │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5 (Conv2D)              │ (None, 16, 16, 256)    │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_bn                    │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_relu (ReLU)           │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_6 (ZeroPadding2D)      │ (None, 17, 17, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6 (DepthwiseConv2D)     │ (None, 8, 8, 256)      │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_bn                    │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_relu (ReLU)           │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6 (Conv2D)              │ (None, 8, 8, 512)      │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7 (DepthwiseConv2D)     │ (None, 8, 8, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7 (Conv2D)              │ (None, 8, 8, 512)      │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8 (DepthwiseConv2D)     │ (None, 8, 8, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8 (Conv2D)              │ (None, 8, 8, 512)      │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9 (DepthwiseConv2D)     │ (None, 8, 8, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9 (Conv2D)              │ (None, 8, 8, 512)      │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_bn                    │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_relu (ReLU)           │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10 (DepthwiseConv2D)    │ (None, 8, 8, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_bn                   │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_relu (ReLU)          │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10 (Conv2D)             │ (None, 8, 8, 512)      │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_bn                   │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_relu (ReLU)          │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11 (DepthwiseConv2D)    │ (None, 8, 8, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_bn                   │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_relu (ReLU)          │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11 (Conv2D)             │ (None, 8, 8, 512)      │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_bn                   │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_relu (ReLU)          │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_12 (ZeroPadding2D)     │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12 (DepthwiseConv2D)    │ (None, 4, 4, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_bn                   │ (None, 4, 4, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_relu (ReLU)          │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12 (Conv2D)             │ (None, 4, 4, 1024)     │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_bn                   │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_relu (ReLU)          │ (None, 4, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13 (DepthwiseConv2D)    │ (None, 4, 4, 1024)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_bn                   │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_relu (ReLU)          │ (None, 4, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13 (Conv2D)             │ (None, 4, 4, 1024)     │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_bn                   │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_relu (ReLU)          │ (None, 4, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,360,193 (12.82 MB)
#  Trainable params: 131,329 (513.00 KB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %% [markdown]
# ### 2.1 Train the MobileNet Model (Nothing to do)
#
# You will now train the model using the training and validation datasets.

# %%
# Train the model
NUM_EPOCHS = 30
history_mobilenet = model_mobilenet.fit(
    train_data,
    validation_data=validation_data,
    epochs=NUM_EPOCHS,  # You can increase the number of epochs based on your needs
    verbose=1
)
# Out:
# Epoch 1/30
# c:\Users\adria\anaconda3\envs\py311_ai4bh\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - accuracy: 0.8231 - loss: 0.3849 - val_accuracy: 0.7982 - val_loss: 0.4972
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9454 - loss: 0.1432 - val_accuracy: 0.9079 - val_loss: 0.2433
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9825 - loss: 0.0617 - val_accuracy: 0.9320 - val_loss: 0.1767
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9978 - loss: 0.0252 - val_accuracy: 0.9298 - val_loss: 0.1734
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.9364 - val_loss: 0.1662
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9298 - val_loss: 0.1620
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9386 - val_loss: 0.1653
# Epoch 8/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9364 - val_loss: 0.1542
# Epoch 9/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9342 - val_loss: 0.1559
# Epoch 10/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9386 - val_loss: 0.1512
# Epoch 11/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9386 - val_loss: 0.1550
# Epoch 12/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9386 - val_loss: 0.1536
# Epoch 13/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9386 - val_loss: 0.1530
# Epoch 14/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9320 - val_loss: 0.1540
# Epoch 15/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9386 - val_loss: 0.1561
# Epoch 16/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9364 - val_loss: 0.1515
# Epoch 17/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9386 - val_loss: 0.1530
# Epoch 18/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9386 - val_loss: 0.1589
# Epoch 19/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9364 - val_loss: 0.1560
# Epoch 20/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 1.0000 - loss: 9.9258e-04 - val_accuracy: 0.9386 - val_loss: 0.1577
# Epoch 21/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 1.0000 - loss: 9.2036e-04 - val_accuracy: 0.9364 - val_loss: 0.1591
# Epoch 22/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 1.0000 - loss: 8.6398e-04 - val_accuracy: 0.9364 - val_loss: 0.1617
# Epoch 23/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 1.0000 - loss: 7.4309e-04 - val_accuracy: 0.9386 - val_loss: 0.1619
# Epoch 24/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 1.0000 - loss: 6.9440e-04 - val_accuracy: 0.9430 - val_loss: 0.1583
# Epoch 25/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 1.0000 - loss: 6.5780e-04 - val_accuracy: 0.9386 - val_loss: 0.1608
# Epoch 26/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 5.7857e-04 - val_accuracy: 0.9386 - val_loss: 0.1598
# Epoch 27/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 5.3696e-04 - val_accuracy: 0.9386 - val_loss: 0.1609
# Epoch 28/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 5.0667e-04 - val_accuracy: 0.9408 - val_loss: 0.1603
# Epoch 29/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 1.0000 - loss: 4.6079e-04 - val_accuracy: 0.9386 - val_loss: 0.1613
# Epoch 30/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 1.0000 - loss: 4.3647e-04 - val_accuracy: 0.9386 - val_loss: 0.1625

# %% [markdown]
# ### 2.2 Visualize the results

# %%
# Evaluate the model
loss, accuracy = model_mobilenet.evaluate(validation_data)
print(f"Validation Accuracy: {accuracy:.2f}")

# Plot training and validation accuracy over epochs
acc = history_mobilenet.history['accuracy']
val_acc = history_mobilenet.history['val_accuracy']
loss = history_mobilenet.history['loss']
val_loss = history_mobilenet.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9386 - loss: 0.1625
# Validation Accuracy: 0.94

# %% [markdown]
# ### 2.3 Compare the performance of your models
#
# **Plot the ROC curves and compute the AUC for each of your trained models**.

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np

# Function to plot ROC curves for multiple models on the same plot
def plot_roc_curves(models, validation_data_list, labels, title="ROC Curve Comparison"):
    plt.figure(figsize=(10, 6))

    # Iterate over each model and its corresponding validation data
    for model, validation_data, label in zip(models, validation_data_list, labels):
        y_true = []
        y_pred = []

        # Get true labels and predicted probabilities
        for images, labels_batch in validation_data:
            y_true.extend(labels_batch)
            preds = model.predict(images)
            y_pred.extend(preds)

            # Break after one full pass (since it's a generator)
            if len(y_true) >= validation_data.samples:
                break

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)

        # Compute False Positive Rate (FPR) and True Positive Rate (TPR)
        fpr, tpr, _ = roc_curve(y_true, y_pred)
        roc_auc = auc(fpr, tpr)

        # Plot the ROC Curve for the current model
        plt.plot(fpr, tpr, lw=2, label=f'{label} (AUC = {roc_auc:.2f})')

    # Plot the random guess line
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random guess line

    # Configure plot settings
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc="lower right")
    plt.show()

# Plot ROC curves for the original model and MobileNet model on the same plot
plot_roc_curves(
    models=[model_mobilenet],
    validation_data_list=[validation_data],
    labels=["MobileNet Model"]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step

# %% [markdown]
# ## 🔆 3. Class Activation Maps
#
# In this section, you need to use the GradCAM approach (https://arxiv.org/abs/1610.02391) to visualize the activation maps on some test images.
# Below, there is a function which implements the GradCAM algorithm. The function needs the image, the trained model and *the name of the last convolutional layer in the model*.

# %%
import numpy as np
from tensorflow.keras.models import Model

def get_img_array(img, size):

    #array = tf.keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    img=np.resize(img,(size,size,3))#.astype(np.float32)
    array = np.expand_dims(img, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    last_conv_layer = model.get_layer(last_conv_layer_name)
    grad_model = Model(inputs=model.input, outputs=[last_conv_layer.output, model.output])

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        #class_channel = preds[:, pred_index]
        class_channel = preds#[:, 0]
    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %% [markdown]
# ### 3.1 GradCAM on our model
#
# We're going to select 16 images from the test set and apply the GradCAM to each of them. To each image an extra dimension is added so that their shape is (1,128,128,3). Why do we need that that?
#
# ❗ You need to call the make_grad_heatmap() function with the right arguments. Hint: look at the model summary to get the names of all the layers.

# %%
import matplotlib.pyplot as plt
img_size=128


image_examples=[]
labels_examples=[]
cam_examples=[]


images, labels=validation_data[1]
  # Prepare image

for layer in model_mobilenet.layers:
    print(layer.name)

  # Iterate over the images and labels in the current batch
for image, label in zip(images, labels):
  image_examples.append(image)
  labels_examples.append(label)

  img_array = tf.expand_dims(image, axis=0)

  # Make model
  model = model_mobilenet

  # Print what the top predicted class is

  preds = model.predict(img_array)
  print("Label: ", label, "Predicted:", preds[0])#decode_predictions(preds, top=1)[0])

  last_conv_layer_name = "conv_pw_13_relu" 
  heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

  cam_examples.append(heatmap)

# Display last heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# input_layer
# conv1
# conv1_bn
# conv1_relu
# conv_dw_1
# conv_dw_1_bn
# conv_dw_1_relu
# conv_pw_1
# conv_pw_1_bn
# conv_pw_1_relu
# conv_pad_2
# conv_dw_2
# conv_dw_2_bn
# conv_dw_2_relu
# conv_pw_2
# conv_pw_2_bn
# conv_pw_2_relu
# conv_dw_3
# conv_dw_3_bn
# conv_dw_3_relu
# conv_pw_3
# conv_pw_3_bn
# conv_pw_3_relu
# conv_pad_4
# conv_dw_4
# conv_dw_4_bn
# conv_dw_4_relu
# conv_pw_4
# conv_pw_4_bn
# conv_pw_4_relu
# conv_dw_5
# conv_dw_5_bn
# conv_dw_5_relu
# conv_pw_5
# conv_pw_5_bn
# conv_pw_5_relu
# conv_pad_6
# conv_dw_6
# conv_dw_6_bn
# conv_dw_6_relu
# conv_pw_6
# conv_pw_6_bn
# conv_pw_6_relu
# conv_dw_7
# conv_dw_7_bn
# conv_dw_7_relu
# conv_pw_7
# conv_pw_7_bn
# conv_pw_7_relu
# conv_dw_8
# conv_dw_8_bn
# conv_dw_8_relu
# conv_pw_8
# conv_pw_8_bn
# conv_pw_8_relu
# conv_dw_9
# conv_dw_9_bn
# conv_dw_9_relu
# conv_pw_9
# conv_pw_9_bn
# conv_pw_9_relu
# conv_dw_10
# conv_dw_10_bn
# conv_dw_10_relu
# conv_pw_10
# conv_pw_10_bn
# conv_pw_10_relu
# conv_dw_11
# conv_dw_11_bn
# conv_dw_11_relu
# conv_pw_11
# conv_pw_11_bn
# conv_pw_11_relu
# conv_pad_12
# conv_dw_12
# conv_dw_12_bn
# conv_dw_12_relu
# conv_pw_12
# conv_pw_12_bn
# conv_pw_12_relu
# conv_dw_13
# conv_dw_13_bn
# conv_dw_13_relu
# conv_pw_13
# conv_pw_13_bn
# conv_pw_13_relu
# global_average_pooling2d
# dense
# dense_1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Label:  0.0 Predicted: [0.00078719]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Label:  0.0 Predicted: [0.00282535]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Label:  0.0 Predicted: [0.0056446]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Label:  1.0 Predicted: [0.99998623]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Label:  0.0 Predicted: [0.00817179]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label:  1.0 Predicted: [0.99999964]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label:  0.0 Predicted: [3.5039484e-05]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Label:  1.0 Predicted: [0.9953061]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label:  0.0 Predicted: [0.02943914]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label:  0.0 Predicted: [0.71137166]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Label:  0.0 Predicted: [0.00012239]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Label:  0.0 Predicted: [0.00484207]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label:  1.0 Predicted: [0.9998905]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Label:  1.0 Predicted: [0.9999997]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Label:  0.0 Predicted: [0.0001324]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Label:  0.0 Predicted: [0.00061112]

# %% [markdown]
# The size of the CAMs is quite small.
# You need to rescale them to the original image size and then superimpose them to the corresponding image. The *display_gradcam* function below creates a transparent heatmap corresponding to the CAM and adds it to the image.
#
# ❗You need to modify this function so that the size of the heatmap equals the size of the image. Easy.
# ❗Equally you need to create a blended image (weighted sum) of the original image and the CAM (use the alpha value to control  transparency)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from matplotlib import cm

def display_gradcam_with_colorbar(img, heatmap, alpha=0.4):
    """
    Superimposes the Grad-CAM heatmap onto the original image and adds a colorbar.

    Args:
    - img: Original image as a NumPy array (H, W, C).
    - heatmap: Grad-CAM heatmap as a NumPy array (H, W).
    - alpha: Intensity factor for the heatmap overlay.

    Returns:
    - superimposed_img: Image with heatmap overlay as a PIL Image.
    """
    # Ensure the image is a NumPy array and normalize it to 0-255
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = (img - img.min()) / (img.max() - img.min())  # Normalize to 0-1
    img = np.uint8(img * 255)  # Scale to 0-255

    # Rescale heatmap to a range of 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize the heatmap
    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]  # RGB values for the colormap
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB heatmap
    jet_heatmap = tf.keras.utils.array_to_img(jet_heatmap)

    # Resize the heatmap to match the size of the original image
    # Get original image dimensions
    (h, w, _) = img.shape
    jet_heatmap = jet_heatmap.resize((w, h))
    jet_heatmap = np.array(jet_heatmap)

    # Superimpose the heatmap on the original image
    superimposed_img = jet_heatmap * alpha + img * (1 - alpha)
    superimposed_img = np.uint8(superimposed_img)
    superimposed_img = tf.keras.utils.array_to_img(superimposed_img)



    return superimposed_img

# Visualize Grad-CAMs for multiple examples
def visualize_gradcams_with_colorbars(image_examples, cam_examples, labels_examples, class_names, rows=4, cols=4):
    """
    Visualizes Grad-CAM heatmaps overlaid on images in a grid format with colorbars.

    Args:
    - image_examples: List or array of input images.
    - cam_examples: List or array of heatmaps corresponding to the images.
    - labels_examples: List or array of true labels for the images.
    - class_names: List of class names corresponding to the labels.
    - rows: Number of rows in the grid.
    - cols: Number of columns in the grid.
    """
    fig, axes = plt.subplots(rows, cols, figsize=(20, 20))

    for j, ax in enumerate(axes.flat):
        if j >= len(image_examples):
            break

        # Display the Grad-CAM superimposed image
        img = display_gradcam_with_colorbar(image_examples[j], cam_examples[j])

        # Show the image without calling plt.show() again
        ax.imshow(img)
        ax.set_title(class_names[int(labels_examples[j])])
        ax.axis('off')
        cbar = fig.colorbar(cm.ScalarMappable(cmap="jet"), ax=ax, orientation="vertical")
        cbar.set_label("Activation Intensity", rotation=270, labelpad=15)


    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming `image_examples`, `cam_examples`, and `labels_examples` are predefined
# and `class_names` contains the class labels (e.g., ['normal', 'tumor'])
visualize_gradcams_with_colorbars(image_examples, cam_examples, labels_examples, class_names=['normal', 'tumor'])
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_6388\286371546.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   jet = cm.get_cmap("jet")

# %% [markdown]
# ## 🔥 4. Pixel-wise saliency maps
#
# ❗ You need to complete the pixel-wise saliency map computation here.
# Have look at this paper : https://arxiv.org/abs/1312.6034
# which does a deep dive into the algorithm. Equally, check out the keras visualisation kit (https://github.com/keisen/tf-keras-vis).

# %%
def compute_saliency_map(model, img_array, class_index=None):
    """
    Computes a pixel-wise saliency map using the gradients of the model's output with respect to the input image.

    Args:
    - model: Trained model.
    - img_array: Preprocessed input image as a NumPy array (1, H, W, C).
    - class_index: Index of the class to compute the saliency for (optional).

    Returns:
    - saliency_map: Saliency map as a NumPy array (H, W).
    """
    # Ensure the input image is wrapped in a batch
    if len(img_array.shape) == 3:
        img_array = np.expand_dims(img_array, axis=0)

    # Use GradientTape to compute gradients
    with tf.GradientTape() as tape:
        # Watch the input image
        tape.watch(img_array)

        # Forward pass
        predictions = model(img_array)

        # Target the specific class or maximum score
        #if class_index is None:
        #    class_index = tf.argmax(predictions[0])

        target_score = predictions#[0]
        #target_score = predictions[:, class_index]

    # Compute the gradient of the target score with respect to the input image
    gradients = tape.gradient(target_score, img_array)

    # Take the absolute value of the gradients and reduce to a single channel
    saliency_map = tf.reduce_mean(tf.abs(gradients), axis=-1)

    # Normalize the saliency map to the range [0, 1]
    saliency_map = (saliency_map - tf.reduce_min(saliency_map)) / (tf.reduce_max(saliency_map) - tf.reduce_min(saliency_map))

    return saliency_map.numpy()

# %% [markdown]
# ❗Display the saliency maps on top of the images in a similar way you did for the GradCAMs.

# %%
def compute_saliency_map(model, img_array, class_index=None):
    """
    Computes a pixel-wise saliency map using the gradients of the model's output 
    with respect to the input image.
    Args:
    - model: Trained model.
    - img_array: Preprocessed input image as a tensor (1, H, W, C).
    - class_index: Index of the class to compute the saliency for (optional).
    Returns:
    - saliency_map: Saliency map as a NumPy array (H, W).
    """
    # Convert to tf.Variable so tape.watch() works
    img_array = tf.Variable(img_array, dtype=tf.float32)
    
    # Use GradientTape to compute gradients
    with tf.GradientTape() as tape:
        tape.watch(img_array)
        # Forward pass
        predictions = model(img_array, training=False)
        
        # For binary classification with sigmoid, use the prediction directly
        target_score = predictions[0]
    
    # Compute the gradient of the target score with respect to the input image
    gradients = tape.gradient(target_score, img_array)
    
    # Take the absolute value and reduce to a single channel
    saliency_map = tf.reduce_max(tf.abs(gradients), axis=-1)
    
    # Remove batch dimension
    saliency_map = tf.squeeze(saliency_map)
    
    # Normalize the saliency map to the range [0, 1]
    saliency_map = (saliency_map - tf.reduce_min(saliency_map)) / (tf.reduce_max(saliency_map) - tf.reduce_min(saliency_map) + 1e-8)
    
    return saliency_map.numpy()

# Generate saliency maps
img_size = 128
image_examples = []
labels_examples = []
sal_examples = []
predictions_list = [] # track predictions 

images, labels = validation_data[1]

# Iterate over the images and labels in the current batch
for image, label in zip(images, labels):
    image_examples.append(image)
    labels_examples.append(label)
    
    img_array = tf.expand_dims(image, axis=0)
    preds = model_mobilenet.predict(img_array)
    predictions_list.append(preds[0][0])  # Store prediction
    print(f"Label: {label} ({'tumor' if label==1 else 'normal'}), Predicted: {preds[0][0]:.4f} ({'tumor' if preds[0][0]>0.5 else 'normal'})")
    
    saliency_map = compute_saliency_map(model_mobilenet, img_array)
    sal_examples.append(saliency_map)

# Display last saliency map
plt.matshow(saliency_map)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Label: 0.0 (normal), Predicted: 0.0008 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Label: 0.0 (normal), Predicted: 0.0028 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Label: 0.0 (normal), Predicted: 0.0056 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Label: 1.0 (tumor), Predicted: 1.0000 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Label: 0.0 (normal), Predicted: 0.0082 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Label: 1.0 (tumor), Predicted: 1.0000 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Label: 0.0 (normal), Predicted: 0.0000 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Label: 1.0 (tumor), Predicted: 0.9953 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Label: 0.0 (normal), Predicted: 0.0294 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Label: 0.0 (normal), Predicted: 0.7114 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Label: 0.0 (normal), Predicted: 0.0001 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Label: 0.0 (normal), Predicted: 0.0048 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Label: 1.0 (tumor), Predicted: 0.9999 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Label: 1.0 (tumor), Predicted: 1.0000 (tumor)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Label: 0.0 (normal), Predicted: 0.0001 (normal)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Label: 0.0 (normal), Predicted: 0.0006 (normal)

# %%
def display_saliency_with_colorbar(img, saliency_map, alpha=0.4):
    """
    Superimposes the saliency map onto the original image and adds a colorbar.
    Args:
    - img: Original image as a NumPy array (H, W, C).
    - saliency_map: Saliency map as a NumPy array (H, W).
    - alpha: Intensity factor for the saliency overlay.
    Returns:
    - superimposed_img: Image with saliency overlay as a PIL Image.
    """
    # Ensure the image is a NumPy array and normalize it to 0-255
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = (img - img.min()) / (img.max() - img.min())  # Normalize to 0-1
    img = np.uint8(img * 255)  # Scale to 0-255
    
    # Rescale saliency map to a range of 0-255
    saliency_map = np.uint8(255 * saliency_map)
    
    # Use jet colormap to colorize the saliency map
    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]  # RGB values for the colormap
    jet_saliency = jet_colors[saliency_map]
    
    # Create an image with RGB saliency map
    jet_saliency = tf.keras.utils.array_to_img(jet_saliency)
    
    # Resize the saliency map to match the size of the original image
    # Get original image dimensions
    (h, w, _) = img.shape
    jet_saliency = jet_saliency.resize((w, h))
    jet_saliency = np.array(jet_saliency)
    
    # Superimpose the saliency map on the original image
    superimposed_img = jet_saliency * alpha + img * (1 - alpha)
    superimposed_img = np.uint8(superimposed_img)
    superimposed_img = tf.keras.utils.array_to_img(superimposed_img)
    
    return superimposed_img

# Visualize saliency maps for multiple examples
def visualize_saliency_maps_with_colorbars(image_examples, saliency_examples, labels_examples, class_names, rows=4, cols=4):
    """
    Visualizes saliency maps overlaid on images in a grid format with colorbars.
    Args:
    - image_examples: List or array of input images.
    - saliency_examples: List or array of saliency maps corresponding to the images.
    - labels_examples: List or array of true labels for the images.
    - class_names: List of class names corresponding to the labels.
    - rows: Number of rows in the grid.
    - cols: Number of columns in the grid.
    """
    fig, axes = plt.subplots(rows, cols, figsize=(20, 20))
    for j, ax in enumerate(axes.flat):
        if j >= len(image_examples):
            break
        # Display the saliency superimposed image
        img = display_saliency_with_colorbar(image_examples[j], saliency_examples[j])
        # Show the image without calling plt.show() again
        ax.imshow(img)
        ax.set_title(class_names[int(labels_examples[j])])
        ax.axis('off')
        cbar = fig.colorbar(cm.ScalarMappable(cmap="jet"), ax=ax, orientation="vertical")
        cbar.set_label("Saliency Intensity", rotation=270, labelpad=15)
    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming `image_examples`, `saliency_examples`, and `labels_examples` are predefined
# and `class_names` contains the class labels (e.g., ['normal', 'tumor'])
visualize_saliency_maps_with_colorbars(image_examples, sal_examples, labels_examples, class_names=['normal', 'tumor'])
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_6388\4067870121.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   jet = cm.get_cmap("jet")

# %% [markdown]
# ❗What do you notice?
#
# ❗Try out SmoothGrad or Integrated Gradients
#
# ❗Try training your model with data augmentation. Do the saliency maps change?
